# %% [markdown]
# <a href="https://colab.research.google.com/github/iAmirHosein92/MachineLearning/blob/main/analysisHeartAttack.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv('heart_2020_cleaned.csv')
display(df.head())
display(df.info())
display(df.describe())
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0           No  16.60     Yes              No     No             3.0
# 1           No  20.34      No              No    Yes             0.0
# 2           No  26.58     Yes              No     No            20.0
# 3           No  24.21      No              No     No             0.0
# 4           No  23.71      No              No     No            28.0
#
#    MentalHealth DiffWalking     Sex  AgeCategory   Race Diabetic  \
# 0          30.0          No  Female        55-59  White      Yes
# 1           0.0          No  Female  80 or older  White       No
# 2          30.0          No    Male        65-69  White      Yes
# 3           0.0          No  Female        75-79  White       No
# 4           0.0         Yes  Female        40-44  White       No
#
#   PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 0              Yes  Very good        5.0    Yes            No        Yes
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns


numerical_cols = df.select_dtypes(include=['number']).columns
categorical_cols = df.select_dtypes(include=['object']).columns

print("Numerical Columns:", numerical_cols.tolist())
print("Categorical Columns:", categorical_cols.tolist())

print("\nNumerical Columns:")
display(df[numerical_cols].describe())


plt.figure(figsize=(20, 15))

for i, col in enumerate(categorical_cols):
    plt.subplot(5, 4, i + 1)
    df[col].value_counts().plot(kind='bar', color='skyblue')
    plt.title(f'{col}')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
plt.show()


for col in categorical_cols:
    if col != 'HeartDisease':
        plt.figure(figsize=(10, 6))
        sns.countplot(x=col, hue='HeartDisease', data=df, palette="viridis")
        plt.title(f'Relationship between {col} and HeartDisease')
        plt.xticks(rotation=45, ha='right')
        plt.tight_layout()
        plt.show()
# Out:
# Numerical Columns: ['BMI', 'PhysicalHealth', 'MentalHealth', 'SleepTime']
# Categorical Columns: ['HeartDisease', 'Smoking', 'AlcoholDrinking', 'Stroke', 'DiffWalking', 'Sex', 'AgeCategory', 'Race', 'Diabetic', 'PhysicalActivity', 'GenHealth', 'Asthma', 'KidneyDisease', 'SkinCancer']
#
# Numerical Columns:
#                  BMI  PhysicalHealth   MentalHealth      SleepTime
# count  319795.000000    319795.00000  319795.000000  319795.000000
# mean       28.325399         3.37171       3.898366       7.097075
# std         6.356100         7.95085       7.955235       1.436007
# min        12.020000         0.00000       0.000000       1.000000
# 25%        24.030000         0.00000       0.000000       6.000000
# 50%        27.340000         0.00000       0.000000       7.000000
# 75%        31.420000         2.00000       3.000000       8.000000
# max        94.850000        30.00000      30.000000      24.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

numerical_features = ['BMI', 'PhysicalHealth', 'MentalHealth', 'SleepTime']
plt.figure(figsize=(15, 10))
for i, feature in enumerate(numerical_features):
    plt.subplot(2, 2, i + 1)
    plt.hist(df[feature], bins=30, color='skyblue', edgecolor='black')
    plt.title(f'{feature}')
    plt.xlabel(feature)
    plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

plt.figure(figsize=(15, 10))
for i, feature in enumerate(numerical_features):
    plt.subplot(2, 2, i + 1)
    sns.boxplot(x=df[feature], color='lightgreen')
    plt.title(f'Box Plot of {feature}')
plt.tight_layout()
plt.show()

plt.figure(figsize=(15, 10))
for i, feature in enumerate(numerical_features):
    plt.subplot(2, 2, i + 1)
    sns.boxplot(x='HeartDisease', y=feature, data=df, palette="Set2")
    plt.title(f'Relationship between {feature} and HeartDisease')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-7-abdb5ade0b41>:28: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='HeartDisease', y=feature, data=df, palette="Set2")
# <ipython-input-7-abdb5ade0b41>:28: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='HeartDisease', y=feature, data=df, palette="Set2")
# <ipython-input-7-abdb5ade0b41>:28: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='HeartDisease', y=feature, data=df, palette="Set2")
# <ipython-input-7-abdb5ade0b41>:28: FutureWarning:
#
# ...
